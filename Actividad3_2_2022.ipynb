# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoHG7/Valores-at-picos/blob/main/Actividad3_2_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("2022.csv")
df
# Out:
#       Unnamed: 0       Fecha       Folio  \
# 0              0  2022-01-01      280108
# 1              1  2022-01-01      280109
# 2              2  2022-01-01  7817297284
# 3              3  2022-01-01        5595
# 4              4  2022-01-01        5614
# ...          ...         ...         ...
# 2572        2572  2022-12-01      863376
# 2573        2573  2022-12-01  1092957089
# 2574        2574  2022-12-01           4
# 2575        2575  2022-12-01          16
# 2576        2576  2022-12-01          17
#
#                                       UUID            RFC  \
# 0     9DA0E63F-1D47-441F-93D7-C2E05AE4D35E   BLE1512082R9
# 1     7E00E776-A839-4D57-B291-411109164B2F   BLE1512082R9
# 2     BB6585C1-3B54-4130-AFD0-1867C3764821   BNM840515VB1
# 3     B5E4B4EB-6C2F-11EC-BB9D-00155D014009  ZEGC530520V4A
# 4     BB6756D1-6CCD-11EC-947D-00155D014407  ZEGC530520V4A
# ...                                    ...            ...
# ...

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
df1 =df.fillna(method="bfill")

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# Fecha          0
# Folio          0
# UUID           0
# RFC            0
# Proveedor      0
# TIPO GASTO     0
# Descripción    0
# MP             0
# TC             0
# Importe        0
# IVA            0
# RET ISR        0
# RET IVA        0
# Otros          0
# TOTAL MX       0
# TOTAL SAT      0
# Tipo           0
# Status         0
# Poliza         0
# dtype: int64

# %%
#Seleccionar las coumnas en cuantitativas
df1s= df.iloc[ : , 9:16] 
df1s
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0   5551.38  888.22      0.0      0.0    0.0   6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    0.0   6440.30
# 2     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 3     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 4     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# ...   ...       ...     ...      ...      ...    ...       ...
# 2572  1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    0.0  17826.62
# 2574  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2575  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2576  0.0      0.00    0.00      0.0      0.0    0.0      0.00
#
# [2577 rows x 7 columns]

# %%
#Variables cualitativas 
df2=df.iloc[ : , [1,2,3,4,5,6,7,8,16,17,18,19]]
df2
# Out:
#            Fecha       Folio                                  UUID  \
# 0     2022-01-01      280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1     2022-01-01      280109  7E00E776-A839-4D57-B291-411109164B2F
# 2     2022-01-01  7817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3     2022-01-01        5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4     2022-01-01        5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...          ...         ...                                   ...
# 2572  2022-12-01      863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573  2022-12-01  1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574  2022-12-01           4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575  2022-12-01          16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576  2022-12-01          17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ...

# %%
df1s = df1s.astype(float)

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
df1s.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
y=df1s
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido TC              5.924609
# Importe     34975.501132
# IVA          5048.646001
# RET ISR       977.619941
# RET IVA      1046.847384
# Otros           0.000000
# TOTAL MX    39054.094273
# dtype: float64
# Limite inferior permitido TC             -4.149576
# Importe    -26990.441616
# IVA         -4069.819702
# RET ISR      -902.558225
# RET IVA      -964.592475
# Otros           0.000000
# TOTAL MX   -30247.525081
# dtype: float64

# %%
#Encontramos Ouliers del Dataframe
outliers= df1s[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#       TC  Importe  IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 1    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 3    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 4    NaN      NaN  NaN      NaN      NaN    NaN       NaN
# ...   ..      ...  ...      ...      ...    ...       ...
# 2572 NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2573 NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2574 NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2575 NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2576 NaN      NaN  NaN      NaN      NaN    NaN       NaN
#
# [2577 rows x 7 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
DF1= df1s[(y<=Limite_Superior)&(y>=Limite_Inferior)]
DF1
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0   5551.38  888.22      0.0      0.0    0.0   6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    0.0   6440.30
# 2     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 3     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 4     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# ...   ...       ...     ...      ...      ...    ...       ...
# 2572  1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    0.0  17826.62
# 2574  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2575  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2576  0.0      0.00    0.00      0.0      0.0    0.0      0.00
#
# [2577 rows x 7 columns]

# %%
valores_nulos=DF1.isnull().sum()
valores_nulos
# Out:
# TC          18
# Importe     36
# IVA         31
# RET ISR     32
# RET IVA     32
# Otros        0
# TOTAL MX    36
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=DF1.copy()
data_clean=data_clean.fillna(round(DF1.mean(),1))
data_clean
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0   5551.38  888.22      0.0      0.0    0.0   6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    0.0   6440.30
# 2     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 3     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 4     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# ...   ...       ...     ...      ...      ...    ...       ...
# 2572  1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    0.0  17826.62
# 2574  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2575  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2576  0.0      0.00    0.00      0.0      0.0    0.0      0.00
#
# [2577 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# TC          0
# Importe     0
# IVA         0
# RET ISR     0
# RET IVA     0
# Otros       0
# TOTAL MX    0
# dtype: int64

# %%
Datos_limpios2020 = pd.concat([df2,DF1], axis=1)
Datos_limpios2020
# Out:
#            Fecha       Folio                                  UUID  \
# 0     2022-01-01      280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1     2022-01-01      280109  7E00E776-A839-4D57-B291-411109164B2F
# 2     2022-01-01  7817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3     2022-01-01        5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4     2022-01-01        5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...          ...         ...                                   ...
# 2572  2022-12-01      863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573  2022-12-01  1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574  2022-12-01           4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575  2022-12-01          16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576  2022-12-01          17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ...

# %%
Datos_limpios2020.to_csv("2022porDataFrame.csv")
from google.colab import files   
files.download("2022porDataFrame.csv")

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=DF1

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido TC             1.0
# Importe     8375.0
# IVA         1000.0
# RET ISR        0.0
# RET IVA        0.0
# Otros          0.0
# TOTAL MX    9609.3
# dtype: float64
# Limite inferior permitido TC             1.00
# Importe    -5025.00
# IVA         -600.00
# RET ISR        0.00
# RET IVA        0.00
# Otros          0.00
# TOTAL MX   -5765.58
# dtype: float64

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= DF1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#        TC  Importe  IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 1     NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2     NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 3     NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 4     NaN      NaN  NaN      NaN      NaN    NaN       NaN
# ...   ...      ...  ...      ...      ...    ...       ...
# 2572  NaN      NaN  NaN      NaN      NaN    NaN       NaN
# 2573  NaN  17310.3  NaN      NaN      NaN    NaN  17826.62
# 2574  0.0      NaN  NaN      NaN      NaN    NaN       NaN
# 2575  0.0      NaN  NaN      NaN      NaN    NaN       NaN
# 2576  0.0      NaN  NaN      NaN      NaN    NaN       NaN
#
# [2577 rows x 7 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= DF1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        TC  Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0  5551.38  888.22      0.0      0.0    0.0    6439.6
# 1     1.0  5551.98  888.32      0.0      0.0    0.0    6440.3
# 2     1.0     0.00    0.00      0.0      0.0    0.0       0.0
# 3     1.0     0.00    0.00      0.0      0.0    0.0       0.0
# 4     1.0     0.00    0.00      0.0      0.0    0.0       0.0
# ...   ...      ...     ...      ...      ...    ...       ...
# 2572  1.0     0.00    0.00      0.0      0.0    0.0       0.0
# 2573  1.0      NaN  516.32      0.0      0.0    0.0       NaN
# 2574  NaN     0.00    0.00      0.0      0.0    0.0       0.0
# 2575  NaN     0.00    0.00      0.0      0.0    0.0       0.0
# 2576  NaN     0.00    0.00      0.0      0.0    0.0       0.0
#
# [2577 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# TC          654
# Importe     323
# IVA         319
# RET ISR      71
# RET IVA      70
# Otros         0
# TOTAL MX    323
# dtype: int64

# %%
DF2=DF1.copy()
DF2=DF2.fillna(round(DF1.mean(),1))
DF2
# Out:
#        TC   Importe     IVA  RET ISR  RET IVA  Otros  TOTAL MX
# 0     1.0   5551.38  888.22      0.0      0.0    0.0   6439.60
# 1     1.0   5551.98  888.32      0.0      0.0    0.0   6440.30
# 2     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 3     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 4     1.0      0.00    0.00      0.0      0.0    0.0      0.00
# ...   ...       ...     ...      ...      ...    ...       ...
# 2572  1.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2573  1.0  17310.30  516.32      0.0      0.0    0.0  17826.62
# 2574  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2575  0.0      0.00    0.00      0.0      0.0    0.0      0.00
# 2576  0.0      0.00    0.00      0.0      0.0    0.0      0.00
#
# [2577 rows x 7 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=DF2.isnull().sum()
valores_nulos
# Out:
# TC          0
# Importe     0
# IVA         0
# RET ISR     0
# RET IVA     0
# Otros       0
# TOTAL MX    0
# dtype: int64

# %%
Datos_limpios2020_iqr = pd.concat([df2,DF2], axis=1)
Datos_limpios2020_iqr
# Out:
#            Fecha       Folio                                  UUID  \
# 0     2022-01-01      280108  9DA0E63F-1D47-441F-93D7-C2E05AE4D35E
# 1     2022-01-01      280109  7E00E776-A839-4D57-B291-411109164B2F
# 2     2022-01-01  7817297284  BB6585C1-3B54-4130-AFD0-1867C3764821
# 3     2022-01-01        5595  B5E4B4EB-6C2F-11EC-BB9D-00155D014009
# 4     2022-01-01        5614  BB6756D1-6CCD-11EC-947D-00155D014407
# ...          ...         ...                                   ...
# 2572  2022-12-01      863376  E90DA089-3C3B-45C8-A19C-B8810D222F60
# 2573  2022-12-01  1092957089  D720ED7C-F370-4236-B269-8873ABB78745
# 2574  2022-12-01           4  0AFD3EB5-F3DD-43EB-B9FA-79D793CFF417
# 2575  2022-12-01          16  E3CA1DA8-581A-5844-80D2-CF0317B3BBEA
# 2576  2022-12-01          17  17178BA2-9CCE-54F8-A4B8-3E5F98D4DB8E
#
#                 RFC                                          Proveedor  \
# 0      BLE1512082R9                       BEPENSA LEASING S.A. DE C.V.
# ...

# %%
Datos_limpios2020_iqr.to_csv("2022porDataFrame_iqr.csv")
from google.colab import files   
files.download("2022porDataFrame_iqr.csv")
