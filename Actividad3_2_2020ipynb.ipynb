# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoHG7/Valores-at-picos/blob/main/Actividad3_2_2020ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("2020.csv")
df
# Out:
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2020-01-01                   39408
# 1              1  2020-01-01  0001010100750847116902
# 2              2  2020-01-01  0001010100752163714102
# 3              3  2020-01-01                    3663
# 4              4  2020-01-01                    2849
# ...          ...         ...                     ...
# 3337        3337  2020-12-01                  125834
# 3338        3338  2020-12-01                   37652
# 3339        3339  2020-12-01                     160
# 3340        3340  2020-12-01                  634875
# 3341        3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# ...

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
df1 =df.fillna(method="bfill") 
df1
# Out:
#       Unnamed: 0       FECHA                   FOLIO  \
# 0              0  2020-01-01                   39408
# 1              1  2020-01-01  0001010100750847116902
# 2              2  2020-01-01  0001010100752163714102
# 3              3  2020-01-01                    3663
# 4              4  2020-01-01                    2849
# ...          ...         ...                     ...
# 3337        3337  2020-12-01                  125834
# 3338        3338  2020-12-01                   37652
# 3339        3339  2020-12-01                     160
# 3340        3340  2020-12-01                  634875
# 3341        3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# ...

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0     0
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# Columna1       0
# dtype: int64

# %%
#Seleccionar las coumnas en cuaantitativas
df1s= df.iloc[ : , 9:14] 
df1s
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA
# 0     1.0      0.00  2248.28      0.0      0.0
# 1     1.0    490.00    78.40      0.0      0.0
# 2     1.0    195.00    31.20      0.0      0.0
# 3     1.0  10694.25  1711.08      0.0      0.0
# 4     1.0      0.00     0.00      0.0      0.0
# ...   ...       ...      ...      ...      ...
# 3337  1.0    129.79    20.21      0.0      0.0
# 3338  1.0   2284.80   365.57      0.0      0.0
# 3339  1.0    163.79    26.21      0.0      0.0
# 3340  1.0      0.00     0.00      0.0      0.0
# 3341  1.0  14889.29     0.00      0.0      0.0
#
# [3342 rows x 5 columns]

# %%
df2s=df.iloc[ : , [1,2,3,4,5,6,8,16,17,18,19]]
df2s
# Out:
#            FECHA                   FOLIO  \
# 0     2020-01-01                   39408
# 1     2020-01-01  0001010100750847116902
# 2     2020-01-01  0001010100752163714102
# 3     2020-01-01                    3663
# 4     2020-01-01                    2849
# ...          ...                     ...
# 3337  2020-12-01                  125834
# 3338  2020-12-01                   37652
# 3339  2020-12-01                     160
# 3340  2020-12-01                  634875
# 3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# 4     EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3  ENA7006081P0
# ...                                    ...           ...
# 3337  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5  SQS110113MU0
# ...

# %%
df1s = df1s.replace({'TC':'0'}, regex=False)
df1s = df1s.replace({"FP":'0'}, regex=False)
df1s = df1s.replace({"IMPORTE":'0'}, regex=False)
df1s = df1s.replace({"Importe":'0'}, regex=False)
df1s = df1s.replace({"IVA":'0'}, regex=False)
df1s = df1s.replace({"RET ISR":'0'}, regex=False)
df1s = df1s.replace({"RET IVA":'0'}, regex=False)

# %%
df1s = df1s.astype(float)

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
df1s.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
y=df1s
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido TC             4.282840
# IMPORTE    25156.362379
# IVA         4558.933842
# RET ISR      667.271992
# RET IVA      958.239955
# dtype: float64
# Limite inferior permitido TC            -2.407013
# IMPORTE   -18921.747418
# IVA        -3590.614194
# RET ISR     -627.750813
# RET IVA     -839.215179
# dtype: float64

# %%
#Encontramos Ouliers del Dataframe
outliers= df1s[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#       TC  IMPORTE  IVA  RET ISR  RET IVA
# 0    NaN      NaN  NaN      NaN      NaN
# 1    NaN      NaN  NaN      NaN      NaN
# 2    NaN      NaN  NaN      NaN      NaN
# 3    NaN      NaN  NaN      NaN      NaN
# 4    NaN      NaN  NaN      NaN      NaN
# ...   ..      ...  ...      ...      ...
# 3337 NaN      NaN  NaN      NaN      NaN
# 3338 NaN      NaN  NaN      NaN      NaN
# 3339 NaN      NaN  NaN      NaN      NaN
# 3340 NaN      NaN  NaN      NaN      NaN
# 3341 NaN      NaN  NaN      NaN      NaN
#
# [3342 rows x 5 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
DF1= df1s[(y<=Limite_Superior)&(y>=Limite_Inferior)]
DF1
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA
# 0     1.0      0.00  2248.28      0.0      0.0
# 1     1.0    490.00    78.40      0.0      0.0
# 2     1.0    195.00    31.20      0.0      0.0
# 3     1.0  10694.25  1711.08      0.0      0.0
# 4     1.0      0.00     0.00      0.0      0.0
# ...   ...       ...      ...      ...      ...
# 3337  1.0    129.79    20.21      0.0      0.0
# 3338  1.0   2284.80   365.57      0.0      0.0
# 3339  1.0    163.79    26.21      0.0      0.0
# 3340  1.0      0.00     0.00      0.0      0.0
# 3341  1.0  14889.29     0.00      0.0      0.0
#
# [3342 rows x 5 columns]

# %%
valores_nulos=DF1.isnull().sum()
valores_nulos
# Out:
# TC          9
# IMPORTE    67
# IVA        58
# RET ISR    21
# RET IVA    74
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=DF1.copy()
data_clean=data_clean.fillna(round(DF1.mean(),1))
data_clean
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA
# 0     1.0      0.00  2248.28      0.0      0.0
# 1     1.0    490.00    78.40      0.0      0.0
# 2     1.0    195.00    31.20      0.0      0.0
# 3     1.0  10694.25  1711.08      0.0      0.0
# 4     1.0      0.00     0.00      0.0      0.0
# ...   ...       ...      ...      ...      ...
# 3337  1.0    129.79    20.21      0.0      0.0
# 3338  1.0   2284.80   365.57      0.0      0.0
# 3339  1.0    163.79    26.21      0.0      0.0
# 3340  1.0      0.00     0.00      0.0      0.0
# 3341  1.0  14889.29     0.00      0.0      0.0
#
# [3342 rows x 5 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# TC         0
# IMPORTE    0
# IVA        0
# RET ISR    0
# RET IVA    0
# dtype: int64

# %%
Datos_limpios2020 = pd.concat([df2s,DF1], axis=1)
Datos_limpios2020
# Out:
#            FECHA                   FOLIO  \
# 0     2020-01-01                   39408
# 1     2020-01-01  0001010100750847116902
# 2     2020-01-01  0001010100752163714102
# 3     2020-01-01                    3663
# 4     2020-01-01                    2849
# ...          ...                     ...
# 3337  2020-12-01                  125834
# 3338  2020-12-01                   37652
# 3339  2020-12-01                     160
# 3340  2020-12-01                  634875
# 3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# 4     EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3  ENA7006081P0
# ...                                    ...           ...
# 3337  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5  SQS110113MU0
# ...

# %%
Datos_limpios2020.to_csv("2020porDataFrame.csv")
from google.colab import files   
files.download("2020porDataFrame.csv")

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=DF1

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido TC            1.0000
# IMPORTE    6306.9925
# IVA         915.2000
# RET ISR       0.0000
# RET IVA       0.0000
# dtype: float64
# Limite inferior permitido TC            1.0000
# IMPORTE   -3784.1875
# IVA        -549.1200
# RET ISR       0.0000
# RET IVA       0.0000
# dtype: float64

# %%
#Encontramos Outliers del Dataframe
outliers_iqr= DF1[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#       TC   IMPORTE      IVA  RET ISR  RET IVA
# 0    NaN       NaN  2248.28      NaN      NaN
# 1    NaN       NaN      NaN      NaN      NaN
# 2    NaN       NaN      NaN      NaN      NaN
# 3    NaN  10694.25  1711.08      NaN      NaN
# 4    NaN       NaN      NaN      NaN      NaN
# ...   ..       ...      ...      ...      ...
# 3337 NaN       NaN      NaN      NaN      NaN
# 3338 NaN       NaN      NaN      NaN      NaN
# 3339 NaN       NaN      NaN      NaN      NaN
# 3340 NaN       NaN      NaN      NaN      NaN
# 3341 NaN  14889.29      NaN      NaN      NaN
#
# [3342 rows x 5 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= DF1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA
# 0     1.0     0.00     NaN      0.0      0.0
# 1     1.0   490.00   78.40      0.0      0.0
# 2     1.0   195.00   31.20      0.0      0.0
# 3     1.0      NaN     NaN      0.0      0.0
# 4     1.0     0.00    0.00      0.0      0.0
# ...   ...      ...     ...      ...      ...
# 3337  1.0   129.79   20.21      0.0      0.0
# 3338  1.0  2284.80  365.57      0.0      0.0
# 3339  1.0   163.79   26.21      0.0      0.0
# 3340  1.0     0.00    0.00      0.0      0.0
# 3341  1.0      NaN    0.00      0.0      0.0
#
# [3342 rows x 5 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# TC         400
# IMPORTE    466
# IVA        475
# RET ISR     45
# RET IVA    253
# dtype: int64

# %%
DF2=DF1.copy()
DF2=DF2.fillna(round(DF1.mean(),1))
DF2
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA
# 0     1.0      0.00  2248.28      0.0      0.0
# 1     1.0    490.00    78.40      0.0      0.0
# 2     1.0    195.00    31.20      0.0      0.0
# 3     1.0  10694.25  1711.08      0.0      0.0
# 4     1.0      0.00     0.00      0.0      0.0
# ...   ...       ...      ...      ...      ...
# 3337  1.0    129.79    20.21      0.0      0.0
# 3338  1.0   2284.80   365.57      0.0      0.0
# 3339  1.0    163.79    26.21      0.0      0.0
# 3340  1.0      0.00     0.00      0.0      0.0
# 3341  1.0  14889.29     0.00      0.0      0.0
#
# [3342 rows x 5 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=DF2.isnull().sum()
valores_nulos
# Out:
# TC         0
# IMPORTE    0
# IVA        0
# RET ISR    0
# RET IVA    0
# dtype: int64

# %%
Datos_limpios2020_iqr = pd.concat([df2s,DF2], axis=1)
Datos_limpios2020_iqr
# Out:
#            FECHA                   FOLIO  \
# 0     2020-01-01                   39408
# 1     2020-01-01  0001010100750847116902
# 2     2020-01-01  0001010100752163714102
# 3     2020-01-01                    3663
# 4     2020-01-01                    2849
# ...          ...                     ...
# 3337  2020-12-01                  125834
# 3338  2020-12-01                   37652
# 3339  2020-12-01                     160
# 3340  2020-12-01                  634875
# 3341  2020-12-01                 1044477
#
#                                       UUID           RFC  \
# 0     BD20F436-72CC-4BE2-AD37-5999D71AA391  ARE080115PBA
# 1     85AEAC2E-6395-44A0-9CB9-754D06893375  BNM840515VB1
# 2     BD0DFE85-D776-41CB-9C5C-4FA7923E687A  BNM840515VB1
# 3     EF4504D6-830D-415C-AF03-80CF54C5E28E  PSS120625C86
# 4     EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3  ENA7006081P0
# ...                                    ...           ...
# 3337  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5  SQS110113MU0
# ...

# %%
Datos_limpios2020_iqr.to_csv("2020porDataFrame_iqr.csv")
from google.colab import files   
files.download("2020porDataFrame_iqr.csv")
